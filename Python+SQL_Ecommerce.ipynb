# %%
import pandas as pd
import mysql.connector
import os

# List of CSV files and their corresponding table names
csv_files = [
    ('customers.csv', 'customers'),
    ('orders.csv', 'orders'),
    ('sellers.csv', 'sellers'),
    ('products.csv', 'products'),
    ('geolocation.csv', 'geolocation'),
    ('payments.csv', 'payments'),
    ('order_items.csv', 'order_items')# Added payments.csv for specific handling
]

# Connect to the MySQL database
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='123456',
    database='ecommerce'
)
cursor = conn.cursor()

# Folder containing the CSV files
folder_path = 'C:/Users/khand/Desktop/Ecommerce'

def get_sql_type(dtype):
    if pd.api.types.is_integer_dtype(dtype):
        return 'INT'
    elif pd.api.types.is_float_dtype(dtype):
        return 'FLOAT'
    elif pd.api.types.is_bool_dtype(dtype):
        return 'BOOLEAN'
    elif pd.api.types.is_datetime64_any_dtype(dtype):
        return 'DATETIME'
    else:
        return 'TEXT'

for csv_file, table_name in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv(file_path)
    
    # Replace NaN with None to handle SQL NULL
    df = df.where(pd.notnull(df), None)
    
    # Debugging: Check for NaN values
    print(f"Processing {csv_file}")
    print(f"NaN values before replacement:\n{df.isnull().sum()}\n")

    # Clean column names
    df.columns = [col.replace(' ', '_').replace('-', '_').replace('.', '_') for col in df.columns]

    # Generate the CREATE TABLE statement with appropriate data types
    columns = ', '.join([f'`{col}` {get_sql_type(df[col].dtype)}' for col in df.columns])
    create_table_query = f'CREATE TABLE IF NOT EXISTS `{table_name}` ({columns})'
    cursor.execute(create_table_query)

    # Insert DataFrame data into the MySQL table
    for _, row in df.iterrows():
        # Convert row to tuple and handle NaN/None explicitly
        values = tuple(None if pd.isna(x) else x for x in row)
        sql = f"INSERT INTO `{table_name}` ({', '.join(['`' + col + '`' for col in df.columns])}) VALUES ({', '.join(['%s'] * len(row))})"
        cursor.execute(sql, values)

    # Commit the transaction for the current CSV file
    conn.commit()

# Close the connection
conn.close()
# Out:
# Processing customers.csv
# NaN values before replacement:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
# Processing orders.csv
# NaN values before replacement:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64
#
# Processing sellers.csv
# NaN values before replacement:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64
#
# Processing products.csv
# NaN values before replacement:
# product_id                      0
# product category              610
# product_name_length           610
# product_description_length    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64
#
# Processing geolocation.csv
# NaN values before replacement:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64
#
# Processing payments.csv
# NaN values before replacement:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64
#
# Processing order_items.csv
# NaN values before replacement:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mysql.connector
import numpy as np

db = mysql.connector.connect(host = "localhost", username = "root", password = "123456", database = "ecommerce")

cur = db.cursor()

# %% [markdown]
# # 1. List all unique cities where customers are located.

# %%
query = """ select distinct customer_city from customers """

cur.execute(query)

data = cur.fetchall()

df = pd.DataFrame(data)
df.head()
# Out:
#                        0
# 0                 franca
# 1  sao bernardo do campo
# 2              sao paulo
# 3        mogi das cruzes
# 4               campinas

# %% [markdown]
# # 2. Count the number of orders placed in 2017.

# %%
query = """ select count(order_id) from orders where year(order_purchase_timestamp) = 2017 """

cur.execute(query)

data = cur.fetchall()

"Total orders placed in 2017 are: ", data[0][0]
# Out:
# ('Total orders placed in 2017 are: ', 586313)

# %% [markdown]
# # 3. Find the total sales per category.

# %%
query = """ select upper(products.product_category) category, 
round(sum(payments.payment_value), 2)
from products join order_items
on products.product_id = order_items.product_id 
join payments
on payments.order_id = order_items.order_id
group by category 
"""

cur.execute(query)

data = cur.fetchall()

#data

df = pd.DataFrame(data, columns = ["Category", "Sales"])
df
# Out:
#                         Category         Sales
# 0                      PERFUMERY  8.695635e+08
# 1           FURNITURE DECORATION  2.454183e+09
# 2                      TELEPHONY  8.354896e+08
# 3   FASHION BAGS AND ACCESSORIES  3.743596e+08
# 4                 BED TABLE BATH  2.938742e+09
# ..                           ...           ...
# 69                CDS MUSIC DVDS  2.058222e+06
# 70                    LA CUISINE  4.999618e+06
# 71   FASHION CHILDREN'S CLOTHING  1.348210e+06
# 72                      PC GAMER  3.731322e+06
# 73        INSURANCE AND SERVICES  5.568592e+05
#
# [74 rows x 2 columns]

# %% [markdown]
# # 4. Calculate the percentage of orders that were paid in installments.

# %%
query = """ select (sum(case when payment_installments >= 1 then 1 
else 0 end))/count(*)*100 from payments
"""

cur.execute(query)

data = cur.fetchall()

"The percentage of orders that were paid in installments is: ", data[0][0]
# Out:
# ('The percentage of orders that were paid in installments is: ',
#  Decimal('99.9981'))

# %% [markdown]
# # 5. Count the number of customers from each state.

# %%
query = """ select customer_state, count(customer_id)
from customers group by customer_state
"""

cur.execute(query)

data = cur.fetchall()

df = pd.DataFrame(data, columns = ["state", "customer_count"])
df = df.sort_values(by = "customer_count", ascending = False)

plt.figure(figsize = (9, 4))
plt.bar(df["state"], df["customer_count"])
plt.xticks(rotation = 90)
plt.xlabel("states")
plt.ylabel("customer_count")
plt.title("Count of Customers by States")
plt.show()

# %% [markdown]
# # 6. Calculate the number of orders per month in 2018.

# %%
query = """ select monthname(order_purchase_timestamp) months, count(order_id)
from orders where year(order_purchase_timestamp) = 2018
group by months
"""

cur.execute(query)

data = cur.fetchall()
df = pd.DataFrame(data, columns = ["months", "order_count"])
o = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]

ax = sns.barplot(x = df["months"], y = df["order_count"], data = df, order = o)
plt.xticks(rotation = 45)
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# # 7. Find the average number of products per order, grouped by customer city.

# %%
query = """ with count_per_order as
(select orders.order_id, orders.customer_id, count(order_items.order_id) as oc
from orders join order_items
on orders.order_id = order_items.order_id
group by orders.order_id, orders.customer_id)

select customers.customer_city, round(avg(count_per_order.oc), 2) average_orders
from customers join count_per_order
on customers.customer_id = count_per_order.customer_id
group by customers.customer_city
"""

cur.execute(query)

data = cur.fetchall()
data
# Out:
# [('treze tilias', Decimal('182.00')),
#  ('indaial', Decimal('159.50')),
#  ('sao jose dos campos', Decimal('162.80')),
#  ('sao paulo', Decimal('165.34')),
#  ('porto alegre', Decimal('168.01')),
#  ('santos', Decimal('166.09')),
#  ('sao francisco do sul', Decimal('176.65')),
#  ('sao vicente', Decimal('156.00')),
#  ('joinville', Decimal('157.68')),
#  ('sao vendelino', Decimal('143.00')),
#  ('belo horizonte', Decimal('163.49')),
#  ('bage', Decimal('149.81')),
#  ('gravatai', Decimal('151.94')),
#  ('sumare', Decimal('161.96')),
#  ('rio de janeiro', Decimal('163.99')),
#  ('navegantes', Decimal('166.06')),
#  ('nova iguacu', Decimal('163.85')),
#  ('chapada do norte', Decimal('143.00')),
#  ('sao bernardo do campo', Decimal('163.34')),
#  ('frederico westphalen', Decimal('153.21')),
#  ('contagem', Decimal('163.62')),
#  ('curitiba', Decimal('165.82')),
#  ('guaranta', Decimal('143.00')),
#  ('miracema', Decimal('150.53')),
#  ('campo grande', Decimal('163.43')),
#  ('sao jose', Decimal('168.54')),
#  ('rodeio', Decimal('163.43')),
#  ('barueri', Decimal('159.67')),
#  ('urussanga', Decimal('143.00')),
#  ('osorio', Decimal('167.51')),
#  ('medina', Decimal('166.83')),
#  ('duque de caxias', Decimal('164.21')),
#  ('coronel joao sa', Decimal('143.00')),
#  ('santa cruz do rio pardo', Decimal('155.26')),
#  ('itapolis', Decimal('168.54')),
#  ('serra', Decimal('157.55')),
#  ('lagoa santa', Decimal('159.97')),
#  ('teresina', Decimal('155.26')),
#  ('sao caetano do sul', Decimal('158.60')),
#  ('astolfo dutra', Decimal('182.00')),
#  ('tarabai', Decimal('143.00')),
#  ('trindade', Decimal('153.21')),
#  ('vila velha', Decimal('157.17')),
#  ('nova prata do iguacu', Decimal('166.83')),
#  ('alagoinhas', Decimal('153.73')),
#  ('itaquaquecetuba', Decimal('150.53')),
#  ('macapa', Decimal('164.19')),
#  ('salvador', Decimal('163.10')),
#  ('osasco', Decimal('163.81')),
#  ('guarulhos', Decimal('161.33')),
#  ('manaus', Decimal('160.49')),
#  ('brasilia', Decimal('161.65')),
#  ('cabo frio', Decimal('163.96')),
#  ('itapetininga', Decimal('174.57')),
#  ('tres rios', Decimal('146.67')),
#  ('antonio carlos', Decimal('143.00')),
#  ('goiania', Decimal('170.06')),
#  ('niteroi', Decimal('165.85')),
#  ('nova friburgo', Decimal('155.39')),
#  ('cotia', Decimal('160.30')),
#  ('guaruja', Decimal('166.62')),
#  ('valenca', Decimal('154.53')),
#  ('ibia', Decimal('196.63')),
#  ('mogi-guacu', Decimal('166.57')),
#  ('campos de julio', Decimal('143.00')),
#  ('nova laranjeiras', Decimal('143.00')),
#  ('ribeirao preto', Decimal('163.83')),
#  ('ipatinga', Decimal('168.92')),
#  ('monnerat', Decimal('143.00')),
#  ('ipero', Decimal('150.94')),
#  ('santo antonio de padua', Decimal('175.29')),
#  ('sao goncalo', Decimal('156.38')),
#  ('natal', Decimal('160.44')),
#  ('farroupilha', Decimal('143.00')),
#  ('taubate', Decimal('162.28')),
#  ('juiz de fora', Decimal('158.78')),
#  ('franca', Decimal('178.97')),
#  ('vargem grande paulista', Decimal('159.25')),
#  ('nhandeara', Decimal('143.00')),
#  ('taboao da serra', Decimal('162.23')),
#  ('vitoria', Decimal('160.40')),
#  ('cascavel', Decimal('172.91')),
#  ('vinhedo', Decimal('174.95')),
#  ('caraguatatuba', Decimal('177.13')),
#  ('florianopolis', Decimal('167.04')),
#  ('canoas', Decimal('159.42')),
#  ('guariba', Decimal('143.00')),
#  ('limeira', Decimal('168.72')),
#  ('tabatinga', Decimal('143.00')),
#  ('chapeco', Decimal('174.93')),
#  ('belford roxo', Decimal('155.88')),
#  ('faxinal dos guedes', Decimal('208.00')),
#  ('montenegro', Decimal('151.94')),
#  ('sao francisco de assis', Decimal('143.00')),
#  ('santa barbara', Decimal('170.50')),
#  ('palhoca', Decimal('171.90')),
#  ('ipiau', Decimal('250.25')),
#  ('cajamar', Decimal('166.11')),
#  ('recife', Decimal('158.19')),
#  ('paranagua', Decimal('173.98')),
#  ('rio das ostras', Decimal('166.13')),
#  ('mirassol', Decimal('152.86')),
#  ('boa esperanca do sul', Decimal('143.00')),
#  ('criciuma', Decimal('175.64')),
#  ('sao leopoldo', Decimal('158.13')),
#  ('xique-xique', Decimal('143.00')),
#  ('sao bento do sul', Decimal('152.75')),
#  ('laranjeiras do sul', Decimal('164.45')),
#  ('cuiaba', Decimal('171.25')),
#  ('ituverava', Decimal('167.66')),
#  ('itajai', Decimal('153.73')),
#  ('santo antonio de jesus', Decimal('157.30')),
#  ('jaboatao dos guararapes', Decimal('152.53')),
#  ('londrina', Decimal('157.16')),
#  ('rafard', Decimal('171.60')),
#  ('uberaba', Decimal('161.16')),
#  ('sao jose dos pinhais', Decimal('156.10')),
#  ('barbacena', Decimal('162.66')),
#  ('correia pinto', Decimal('156.00')),
#  ('sao carlos', Decimal('167.63')),
#  ('sao roque', Decimal('166.83')),
#  ('alvorada', Decimal('153.21')),
#  ('joao pessoa', Decimal('168.33')),
#  ('sao borja', Decimal('143.00')),
#  ('fortaleza', Decimal('160.16')),
#  ('santo andre', Decimal('160.67')),
#  ('bonfim paulista', Decimal('182.72')),
#  ('cubatao', Decimal('157.48')),
#  ('guapore', Decimal('222.44')),
#  ('muriae', Decimal('165.34')),
#  ('belem', Decimal('157.78')),
#  ('francisco morato', Decimal('159.05')),
#  ('videira', Decimal('167.34')),
#  ('petropolis', Decimal('169.44')),
#  ('senges', Decimal('200.20')),
#  ('indaiatuba', Decimal('168.72')),
#  ('botelhos', Decimal('160.88')),
#  ('americana', Decimal('169.53')),
#  ('mata verde', Decimal('190.67')),
#  ('ananas', Decimal('143.00')),
#  ('aracatuba', Decimal('167.69')),
#  ('santa rosa de viterbo', Decimal('194.07')),
#  ('apucarana', Decimal('181.50')),
#  ('panorama', Decimal('143.00')),
#  ('mogi das cruzes', Decimal('166.02')),
#  ('guarapuava', Decimal('169.81')),
#  ('camacari', Decimal('175.82')),
#  ('uberlandia', Decimal('156.84')),
#  ('queimados', Decimal('174.78')),
#  ('caxias do sul', Decimal('160.24')),
#  ('sorocaba', Decimal('161.10')),
#  ('jaragua do sul', Decimal('178.35')),
#  ('alta floresta', Decimal('178.75')),
#  ('barra mansa', Decimal('159.55')),
#  ('bauru', Decimal('157.83')),
#  ('cacapava', Decimal('166.19')),
#  ('rio formoso', Decimal('143.00')),
#  ('taquarituba', Decimal('160.88')),
#  ('marau', Decimal('162.50')),
#  ('buritizeiro', Decimal('222.44')),
#  ('artur nogueira', Decimal('174.39')),
#  ('campinas', Decimal('165.52')),
#  ('aparecida de goiania', Decimal('158.60')),
#  ('sao sepe', Decimal('190.67')),
#  ('pelotas', Decimal('161.65')),
#  ('aguai', Decimal('271.70')),
#  ('franco da rocha', Decimal('150.87')),
#  ('marilia', Decimal('152.48')),
#  ('agua doce do norte', Decimal('178.75')),
#  ('novo gama', Decimal('143.00')),
#  ('canarana', Decimal('156.00')),
#  ('piracicaba', Decimal('161.75')),
#  ('pontal', Decimal('166.83')),
#  ('jundiai', Decimal('167.51')),
#  ('maringa', Decimal('169.78')),
#  ('campos novos', Decimal('224.71')),
#  ('dracena', Decimal('201.26')),
#  ('montes claros', Decimal('161.98')),
#  ('teresopolis', Decimal('155.02')),
#  ('rio grande', Decimal('152.23')),
#  ('araraquara', Decimal('167.14')),
#  ('candiota', Decimal('143.00')),
#  ('catanduva', Decimal('156.35')),
#  ('porto feliz', Decimal('169.00')),
#  ('palmeira dos indios', Decimal('143.00')),
#  ('dumont', Decimal('143.00')),
#  ('coromandel', Decimal('171.60')),
#  ('bom despacho', Decimal('161.82')),
#  ('santana de parnaiba', Decimal('167.36')),
#  ('conceicao dos ouros', Decimal('143.00')),
#  ('cajueiro', Decimal('143.00')),
#  ('campo bom', Decimal('166.83')),
#  ('araras', Decimal('173.43')),
#  ('aracaju', Decimal('157.95')),
#  ('itacare', Decimal('143.00')),
#  ('icara', Decimal('190.67')),
#  ('vacaria', Decimal('161.65')),
#  ('diadema', Decimal('166.16')),
#  ('ouro preto', Decimal('165.98')),
#  ('ribeirao pires', Decimal('160.37')),
#  ('atibaia', Decimal('166.68')),
#  ('coxim', Decimal('169.00')),
#  ('macae', Decimal('164.12')),
#  ('barrinha', Decimal('157.30')),
#  ('volta redonda', Decimal('157.43')),
#  ('guaratingueta', Decimal('156.41')),
#  ('campina grande', Decimal('157.72')),
#  ('cachoeiro de itapemirim', Decimal('159.55')),
#  ('arapoti', Decimal('158.89')),
#  ('itaipava', Decimal('178.75')),
#  ('birigui', Decimal('174.17')),
#  ('trajano de moraes', Decimal('143.00')),
#  ('bambui', Decimal('150.94')),
#  ('coronel fabriciano', Decimal('149.98')),
#  ('juazeiro', Decimal('159.25')),
#  ('sao jose da lapa', Decimal('143.00')),
#  ('dourados', Decimal('165.34')),
#  ('ubatuba', Decimal('163.70')),
#  ('santa rita do sapucai', Decimal('155.26')),
#  ('chavantes', Decimal('143.00')),
#  ('olinda', Decimal('150.69')),
#  ('guaratinga', Decimal('143.00')),
#  ('rio negro', Decimal('143.00')),
#  ('vargem grande', Decimal('143.00')),
#  ('arapora', Decimal('171.60')),
#  ('pedra bela', Decimal('143.00')),
#  ('blumenau', Decimal('162.88')),
#  ('agua fria de goias', Decimal('143.00')),
#  ('campo formoso', Decimal('157.30')),
#  ('adamantina', Decimal('150.94')),
#  ('feira de santana', Decimal('152.28')),
#  ('quirinopolis', Decimal('163.43')),
#  ('itarare', Decimal('199.18')),
#  ('ponta grossa', Decimal('164.15')),
#  ('poco verde', Decimal('143.00')),
#  ('itapetinga', Decimal('150.94')),
#  ('pedro velho', Decimal('143.00')),
#  ('cerquilho', Decimal('166.83')),
#  ('paracatu', Decimal('174.78')),
#  ('pitanga', Decimal('143.00')),
#  ('paraopeba', Decimal('143.00')),
#  ('itapevi', Decimal('164.03')),
#  ('carmo', Decimal('165.00')),
#  ('pato branco', Decimal('178.08')),
#  ('japeri', Decimal('189.26')),
#  ('sao jose do rio preto', Decimal('163.18')),
#  ('campos dos goytacazes', Decimal('155.02')),
#  ('rio brilhante', Decimal('143.00')),
#  ('vargem bonita', Decimal('171.60')),
#  ('balneario camboriu', Decimal('170.17')),
#  ('forquilhinha', Decimal('187.00')),
#  ('jau', Decimal('164.55')),
#  ('sobral', Decimal('147.09')),
#  ('tres pontas', Decimal('143.00')),
#  ('paulinia', Decimal('159.63')),
#  ('foz do iguacu', Decimal('161.08')),
#  ('carapicuiba', Decimal('165.44')),
#  ('bilac', Decimal('178.75')),
#  ('itabuna', Decimal('157.07')),
#  ('desembargador otoni', Decimal('143.00')),
#  ('lagoinha', Decimal('143.00')),
#  ('seropedica', Decimal('177.67')),
#  ('mangaratiba', Decimal('166.83')),
#  ('avare', Decimal('158.89')),
#  ('piracuruca', Decimal('143.00')),
#  ('sao joao nepomuceno', Decimal('234.93')),
#  ('sao jose do norte', Decimal('163.43')),
#  ('lauro muller', Decimal('143.00')),
#  ('itapecerica da serra', Decimal('159.05')),
#  ('pirai', Decimal('181.13')),
#  ('votuporanga', Decimal('172.51')),
#  ('jandira', Decimal('170.24')),
#  ('curvelo', Decimal('166.28')),
#  ('patos', Decimal('151.94')),
#  ('pindamonhangaba', Decimal('151.50')),
#  ('cruzeiro', Decimal('173.64')),
#  ('sao jorge do ivai', Decimal('286.00')),
#  ('eugenopolis', Decimal('143.00')),
#  ('bebedouro', Decimal('168.24')),
#  ('valparaiso de goias', Decimal('162.32')),
#  ('aracati', Decimal('156.00')),
#  ('itapaci', Decimal('178.75')),
#  ('limoeiro', Decimal('143.00')),
#  ('sao joao da boa vista', Decimal('167.72')),
#  ('carlos barbosa', Decimal('158.05')),
#  ('manhuacu', Decimal('174.28')),
#  ('vicosa', Decimal('169.71')),
#  ('sao luis', Decimal('160.67')),
#  ('sao joao da barra', Decimal('152.53')),
#  ('rio claro', Decimal('169.75')),
#  ('santa clara do sul', Decimal('214.50')),
#  ('lages', Decimal('163.43')),
#  ('itabaianinha', Decimal('214.50')),
#  ('bom jesus', Decimal('143.00')),
#  ('monte alto', Decimal('147.33')),
#  ('lorena', Decimal('161.95')),
#  ('divinopolis', Decimal('173.72')),
#  ('ipiranga do norte', Decimal('143.00')),
#  ('tres coracoes', Decimal('181.37')),
#  ('tombos', Decimal('143.00')),
#  ('bom jesus dos perdoes', Decimal('151.41')),
#  ('viamao', Decimal('166.51')),
#  ('porto franco', Decimal('143.00')),
#  ('petrolina', Decimal('151.80')),
#  ('faxinal', Decimal('143.00')),
#  ('santa fe do sul', Decimal('143.00')),
#  ('descalvado', Decimal('154.00')),
#  ('jaboticabal', Decimal('158.89')),
#  ('mossoro', Decimal('154.92')),
#  ('cidreira', Decimal('143.00')),
#  ('jaguariaiva', Decimal('150.94')),
#  ('sao jose da tapera', Decimal('143.00')),
#  ('tocos', Decimal('143.00')),
#  ('irati', Decimal('149.50')),
#  ('valinhos', Decimal('168.79')),
#  ('guaiuba', Decimal('143.00')),
#  ('itau de minas', Decimal('143.00')),
#  ('rio do sul', Decimal('175.69')),
#  ('jussara', Decimal('143.00')),
#  ('piumhii', Decimal('153.21')),
#  ('cruz das almas', Decimal('158.89')),
#  ('uba', Decimal('183.47')),
#  ('rio branco', Decimal('158.46')),
#  ('araruama', Decimal('165.29')),
#  ('sandolandia', Decimal('143.00')),
#  ('januaria', Decimal('169.00')),
#  ('italva', Decimal('153.21')),
#  ('guaracai', Decimal('200.20')),
#  ('cachoeira paulista', Decimal('154.44')),
#  ('betim', Decimal('157.23')),
#  ('bonfim', Decimal('143.00')),
#  ('ibiruba', Decimal('170.24')),
#  ('divino', Decimal('153.21')),
#  ('umuarama', Decimal('143.00')),
#  ('sinop', Decimal('182.00')),
#  ('araucaria', Decimal('172.13')),
#  ('caceres', Decimal('177.32')),
#  ('picos', Decimal('158.89')),
#  ('santarem', Decimal('152.75')),
#  ('monte aprazivel', Decimal('171.60')),
#  ('ourinhos', Decimal('174.57')),
#  ('espumoso', Decimal('183.86')),
#  ('rancharia', Decimal('156.00')),
#  ('varginha', Decimal('159.07')),
#  ('cariacica', Decimal('162.69')),
#  ('santa luzia', Decimal('163.43')),
#  ('pirassununga', Decimal('153.36')),
#  ('campos do jordao', Decimal('148.50')),
#  ('linhares', Decimal('169.40')),
#  ('urutai', Decimal('143.00')),
#  ('fazenda rio grande', Decimal('147.93')),
#  ('salto', Decimal('155.17')),
#  ('lucas do rio verde', Decimal('178.75')),
#  ('almirante tamandare', Decimal('155.26')),
#  ('gravata', Decimal('195.00')),
#  ('fernao', Decimal('143.00')),
#  ('porto esperidiao', Decimal('143.00')),
#  ('capelinha', Decimal('150.53')),
#  ('barbalha', Decimal('143.00')),
#  ('carmo do rio claro', Decimal('254.22')),
#  ('itaguai', Decimal('148.96')),
#  ('saudade do iguacu', Decimal('143.00')),
#  ('praia grande', Decimal('163.23')),
#  ('ibatiba', Decimal('143.00')),
#  ('querencia', Decimal('157.30')),
#  ('sao pedro da aldeia', Decimal('155.43')),
#  ('uruacu', Decimal('159.82')),
#  ('para de minas', Decimal('158.46')),
#  ('matipo', Decimal('143.00')),
#  ('lauro de freitas', Decimal('162.07')),
#  ('chacara', Decimal('143.00')),
#  ('sao jose da coroa grande', Decimal('143.00')),
#  ('sao mateus', Decimal('152.13')),
#  ('sao joao da urtiga', Decimal('143.00')),
#  ('cruzeiro do sul', Decimal('143.00')),
#  ('poa', Decimal('168.24')),
#  ('cosmopolis', Decimal('165.00')),
#  ('nucleo residencial pilar', Decimal('160.88')),
#  ('mantena', Decimal('182.00')),
#  ('guaxupe', Decimal('158.46')),
#  ('cachoeira do sul', Decimal('156.41')),
#  ('nova odessa', Decimal('169.34')),
#  ('amparo', Decimal('160.33')),
#  ('santa maria', Decimal('168.41')),
#  ('pradopolis', Decimal('171.60')),
#  ('piratininga', Decimal('158.89')),
#  ('bertioga', Decimal('157.90')),
#  ('sao joaquim da barra', Decimal('172.44')),
#  ('carai', Decimal('190.67')),
#  ('coelho neto', Decimal('143.00')),
#  ('resende', Decimal('167.44')),
#  ('jequie', Decimal('151.41')),
#  ('silvianopolis', Decimal('143.00')),
#  ('teixeira de freitas', Decimal('147.93')),
#  ('nova venecia', Decimal('143.00')),
#  ('venda nova do imigrante', Decimal('209.73')),
#  ('tijucas', Decimal('143.00')),
#  ('campo largo', Decimal('166.19')),
#  ('cambe', Decimal('158.89')),
#  ('porangatu', Decimal('154.00')),
#  ('araguari', Decimal('153.59')),
#  ('patrocinio', Decimal('174.09')),
#  ('itapira', Decimal('158.89')),
#  ('santo amaro da imperatriz', Decimal('166.83')),
#  ('campos borges', Decimal('143.00')),
#  ('entre rios', Decimal('143.00')),
#  ('nova monte verde', Decimal('190.67')),
#  ('itajuba', Decimal('164.30')),
#  ('aracruz', Decimal('150.15')),
#  ('pouso alegre', Decimal('161.56')),
#  ('paulista', Decimal('170.24')),
#  ('sao jose de uba', Decimal('143.00')),
#  ('barra do pirai', Decimal('145.65')),
#  ('teofilo otoni', Decimal('179.23')),
#  ('campina grande do sul', Decimal('157.30')),
#  ('hortolandia', Decimal('156.81')),
#  ('perdizes', Decimal('178.75')),
#  ('votorantim', Decimal('166.55')),
#  ('guarapari', Decimal('157.94')),
#  ('conselheiro lafaiete', Decimal('148.11')),
#  ('botucatu', Decimal('159.99')),
#  ('mairipora', Decimal('158.25')),
#  ('patos de minas', Decimal('148.72')),
#  ('congonhas', Decimal('166.83')),
#  ('glaura', Decimal('143.00')),
#  ('bom jesus do querendo', Decimal('143.00')),
#  ('bituruna', Decimal('143.00')),
#  ('baixo guandu', Decimal('196.63')),
#  ('jatai', Decimal('158.89')),
#  ('capanema', Decimal('187.00')),
#  ('pedreira', Decimal('154.92')),
#  ('maua', Decimal('155.10')),
#  ('maceio', Decimal('151.14')),
#  ('iguaba grande', Decimal('195.68')),
#  ('brejo da madre de deus', Decimal('143.00')),
#  ('embu', Decimal('195.00')),
#  ('cajuru', Decimal('143.00')),
#  ('forquilha', Decimal('143.00')),
#  ('sao jose do rio pardo', Decimal('165.75')),
#  ('moreno', Decimal('200.20')),
#  ('leme', Decimal('151.58')),
#  ('itanhem', Decimal('143.00')),
#  ('guapimirim', Decimal('149.50')),
#  ('cafeara', Decimal('214.50')),
#  ('lajeado', Decimal('162.63')),
#  ('boa vista', Decimal('162.07')),
#  ('cachoeira de minas', Decimal('143.00')),
#  ('matozinhos', Decimal('143.00')),
#  ('jales', Decimal('157.79')),
#  ('sao sebastiao do paraiso', Decimal('151.17')),
#  ('bonfinopolis', Decimal('286.00')),
#  ('almenara', Decimal('163.43')),
#  ('itapecerica', Decimal('143.00')),
#  ('juquitiba', Decimal('170.24')),
#  ('corumba', Decimal('180.07')),
#  ('esteio', Decimal('160.44')),
#  ('cedro', Decimal('143.00')),
#  ('itaberaba', Decimal('143.00')),
#  ('juscimeira', Decimal('143.00')),
#  ('palmas', Decimal('171.86')),
#  ("santa barbara d'oeste", Decimal('163.60')),
#  ('itanhaem', Decimal('191.87')),
#  ('ponta pora', Decimal('182.72')),
#  ('rio bonito', Decimal('153.21')),
#  ('araquari', Decimal('182.00')),
#  ('monte mor', Decimal('154.00')),
#  ('pocos de caldas', Decimal('181.45')),
#  ('floresta', Decimal('156.00')),
#  ('campo belo', Decimal('143.00')),
#  ('sao bento do sapucai', Decimal('163.43')),
#  ('sao miguel do oeste', Decimal('171.60')),
#  ('barretos', Decimal('164.55')),
#  ('afonso claudio', Decimal('143.00')),
#  ('novo horizonte', Decimal('158.89')),
#  ('pires do rio', Decimal('202.58')),
#  ('jambeiro', Decimal('214.50')),
#  ('ouro branco', Decimal('156.95')),
#  ('anapolis', Decimal('162.15')),
#  ('marialva', Decimal('169.81')),
#  ('marica', Decimal('159.58')),
#  ('diamantina', Decimal('153.59')),
#  ('sao lourenco do sul', Decimal('153.21')),
#  ('serrinha', Decimal('162.07')),
#  ('vitoria da conquista', Decimal('166.83')),
#  ('castro', Decimal('195.00')),
#  ('aruana', Decimal('143.00')),
#  ('campo mourao', Decimal('163.43')),
#  ('jacarei', Decimal('157.08')),
#  ('uniao da vitoria', Decimal('231.76')),
#  ('monte carmelo', Decimal('148.96')),
#  ('cerqueira cesar', Decimal('166.83')),
#  ('caete', Decimal('148.30')),
#  ('colniza', Decimal('143.00')),
#  ('pinhais', Decimal('157.94')),
#  ('salgueiro', Decimal('143.00')),
#  ('embu-guacu', Decimal('177.20')),
#  ('itauna', Decimal('160.56')),
#  ('buenopolis', Decimal('171.60')),
#  ('santa adelia', Decimal('152.53')),
#  ('vassouras', Decimal('177.78')),
#  ('prado', Decimal('143.00')),
#  ('morungaba', Decimal('143.00')),
#  ('fernandopolis', Decimal('156.49')),
#  ('canela', Decimal('159.82')),
#  ('loanda', Decimal('165.00')),
#  ('prata', Decimal('143.00')),
#  ('terra roxa', Decimal('166.83')),
#  ('senhor do bonfim', Decimal('188.16')),
#  ('registro', Decimal('155.43')),
#  ('tupa', Decimal('167.75')),
#  ('suzano', Decimal('157.73')),
#  ('encruzilhada do sul', Decimal('143.00')),
#  ('ribeirao das neves', Decimal('171.89')),
#  ('urucuca', Decimal('143.00')),
#  ('ivora', Decimal('143.00')),
#  ('mage', Decimal('171.34')),
#  ('cornelio procopio', Decimal('148.96')),
#  ('buriti dos lopes', Decimal('143.00')),
#  ('sorriso', Decimal('178.75')),
#  ('ibiraci', Decimal('143.00')),
#  ('governador valadares', Decimal('156.37')),
#  ('santa maria da vitoria', Decimal('165.00')),
#  ('salto de pirapora', Decimal('154.00')),
#  ('juina', Decimal('151.41')),
#  ('aluminio', Decimal('154.00')),
#  ('garca', Decimal('168.54')),
#  ('itatiaia', Decimal('150.94')),
#  ('guararapes', Decimal('165.58')),
#  ('rolandia', Decimal('180.07')),
#  ('taperuaba', Decimal('143.00')),
#  ('parnamirim', Decimal('158.89')),
#  ('mongagua', Decimal('156.62')),
#  ('guacui', Decimal('160.88')),
#  ('santa isabel', Decimal('162.72')),
#  ('espigao do oeste', Decimal('143.00')),
#  ('carmo do paranaiba', Decimal('160.88')),
#  ('arapiraca', Decimal('167.66')),
#  ('agudos', Decimal('151.94')),
#  ('ribeira', Decimal('143.00')),
#  ('santa ines', Decimal('171.60')),
#  ('assis', Decimal('171.94')),
#  ('dourado', Decimal('174.78')),
#  ('camaragibe', Decimal('147.09')),
#  ('barra do garcas', Decimal('200.20')),
#  ('peabiru', Decimal('143.00')),
#  ('caieiras', Decimal('148.72')),
#  ('itabira', Decimal('171.96')),
#  ('caruaru', Decimal('180.98')),
#  ('monte santo de minas', Decimal('143.00')),
#  ('biguacu', Decimal('143.00')),
#  ('tres lagoas', Decimal('160.02')),
#  ('sete lagoas', Decimal('156.51')),
#  ('taguatinga', Decimal('245.14')),
#  ('regeneracao', Decimal('143.00')),
#  ('formosa da serra negra', Decimal('143.00')),
#  ('nova xavantina', Decimal('157.30')),
#  ('tatui', Decimal('162.59')),
#  ('ferraz de vasconcelos', Decimal('163.61')),
#  ('ivoti', Decimal('143.00')),
#  ('arcos', Decimal('160.16')),
#  ('castanhal', Decimal('170.24')),
#  ('armacao dos buzios', Decimal('147.93')),
#  ('alfenas', Decimal('176.26')),
#  ('nossa senhora do remedio', Decimal('143.00')),
#  ('conquista', Decimal('143.00')),
#  ('sao joao do piaui', Decimal('190.67')),
#  ('brasilia de minas', Decimal('158.89')),
#  ('sao sebastiao', Decimal('185.90')),
#  ('dom eliseu', Decimal('171.60')),
#  ('inhumas', Decimal('151.94')),
#  ('pontal do parana', Decimal('143.00')),
#  ('cedro de sao joao', Decimal('143.00')),
#  ('vila muriqui', Decimal('143.00')),
#  ('turvo', Decimal('143.00')),
#  ('itatiba', Decimal('157.74')),
#  ('passo fundo', Decimal('163.25')),
#  ('boituva', Decimal('163.43')),
#  ('barreiras', Decimal('162.25')),
#  ('gurupi', Decimal('160.88')),
#  ('taio', Decimal('171.60')),
#  ('peruibe', Decimal('208.00')),
#  ('santa rita do passa quatro', Decimal('174.78')),
#  ('arroio do sal', Decimal('183.86')),
#  ('palma', Decimal('143.00')),
#  ('alfredo chaves', Decimal('143.00')),
#  ('ilhabela', Decimal('158.89')),
#  ('bento goncalves', Decimal('163.80')),
#  ('monte belo', Decimal('228.80')),
#  ('fraiburgo', Decimal('143.00')),
#  ('icem', Decimal('174.78')),
#  ('penapolis', Decimal('185.51')),
#  ('braganca paulista', Decimal('158.89')),
#  ('campos altos', Decimal('143.00')),
#  ('canoinhas', Decimal('148.30')),
#  ('passa tres', Decimal('143.00')),
#  ('charqueada', Decimal('143.00')),
#  ('juvenilia', Decimal('214.50')),
#  ('primavera do leste', Decimal('158.32')),
#  ('miguelopolis', Decimal('143.00')),
#  ('juazeiro do norte', Decimal('164.03')),
#  ('paranavai', Decimal('177.20')),
#  ('janauba', Decimal('235.53')),
#  ('feliz', Decimal('153.21')),
#  ('novo hamburgo', Decimal('173.48')),
#  ('poxoreu', Decimal('143.00')),
#  ('planaltina', Decimal('157.30')),
#  ('guaruja do sul', Decimal('143.00')),
#  ('mineiros', Decimal('171.60')),
#  ('mirandopolis', Decimal('165.00')),
#  ('rubiataba', Decimal('204.29')),
#  ('mococa', Decimal('168.24')),
#  ('toledo', Decimal('155.26')),
#  ('presidente epitacio', Decimal('161.65')),
#  ('paiva', Decimal('143.00')),
#  ('carangola', Decimal('169.48')),
#  ('santa vitoria', Decimal('143.00')),
#  ('sao francisco do guapore', Decimal('143.00')),
#  ('camboriu', Decimal('168.54')),
#  ('aparecida do taboado', Decimal('245.14')),
#  ('nova bassano', Decimal('178.75')),
#  ('inga', Decimal('143.00')),
#  ('japi', Decimal('143.00')),
#  ('formiga', Decimal('151.94')),
#  ('cipo-guacu', Decimal('143.00')),
#  ('formosa', Decimal('164.03')),
#  ('petrolandia', Decimal('153.21')),
#  ('sao miguel do aleixo', Decimal('143.00')),
#  ('lencois paulista', Decimal('152.98')),
#  ('terra boa', Decimal('143.00')),
#  ('arapongas', Decimal('172.44')),
#  ('ipameri', Decimal('154.00')),
#  ('xaxim', Decimal('143.00')),
#  ('olimpia', Decimal('158.46')),
#  ('maioba', Decimal('143.00')),
#  ('sao joao de meriti', Decimal('167.92')),
#  ('santa cruz do sul', Decimal('184.52')),
#  ('cortes', Decimal('143.00')),
#  ('barauna', Decimal('143.00')),
#  ('minacu', Decimal('156.00')),
#  ('quintana', Decimal('143.00')),
#  ('banabuiu', Decimal('143.00')),
#  ('rainha do mar', Decimal('143.00')),
#  ('corbelia', Decimal('143.00')),
#  ('marituba', Decimal('143.00')),
#  ('mario campos', Decimal('190.67')),
#  ('porto seguro', Decimal('182.33')),
#  ('formoso do araguaia', Decimal('143.00')),
#  ('ponte nova', Decimal('168.03')),
#  ('alegre', Decimal('151.41')),
#  ('soledade', Decimal('143.00')),
#  ('paraiba do sul', Decimal('158.89')),
#  ('tangara da serra', Decimal('143.00')),
#  ('igaratinga', Decimal('143.00')),
#  ('piraju', Decimal('198.61')),
#  ('santiago', Decimal('181.50')),
#  ('pedro leopoldo', Decimal('178.75')),
#  ('campo limpo paulista', Decimal('151.94')),
#  ('pinhalzinho', Decimal('183.86')),
#  ('crisolita', Decimal('143.00')),
#  ('lagoa dos gatos', Decimal('143.00')),
#  ('felipe guerra', Decimal('143.00')),
#  ('monte castelo', Decimal('143.00')),
#  ('cordeiro', Decimal('148.96')),
#  ('maracaju', Decimal('176.00')),
#  ('arraias', Decimal('143.00')),
#  ('itaobim', Decimal('166.83')),
#  ('joanopolis', Decimal('143.00')),
#  ('santo antonio do caiua', Decimal('286.00')),
#  ('capitao leonidas marques', Decimal('171.60')),
#  ('cachoeiras de macacu', Decimal('156.62')),
#  ('rosario do sul', Decimal('214.50')),
#  ('embu das artes', Decimal('153.46')),
#  ('eunapolis', Decimal('158.05')),
#  ('igarata', Decimal('143.00')),
#  ('concordia', Decimal('183.04')),
#  ('david canabarro', Decimal('214.50')),
#  ('leopoldina', Decimal('168.24')),
#  ('ibiuna', Decimal('166.06')),
#  ('bicas', Decimal('163.43')),
#  ('ecoporanga', Decimal('143.00')),
#  ('tres marias', Decimal('143.00')),
#  ('lavras da mangabeira', Decimal('143.00')),
#  ('nova lima', Decimal('151.76')),
#  ('rio novo do sul', Decimal('166.83')),
#  ('itaborai', Decimal('152.53')),
#  ('redentora', Decimal('143.00')),
#  ('ariquemes', Decimal('231.00')),
#  ('eusebio', Decimal('231.00')),
#  ('aracoiaba da serra', Decimal('156.00')),
#  ('tambau', Decimal('158.05')),
#  ('quatigua', Decimal('143.00')),
#  ('andradina', Decimal('169.60')),
#  ('goioere', Decimal('156.00')),
#  ('liberdade', Decimal('143.00')),
#  ('sertaozinho', Decimal('170.68')),
#  ('sapucaia do sul', Decimal('175.18')),
#  ('araruna', Decimal('143.00')),
#  ('piracaia', Decimal('162.50')),
#  ('lavras', Decimal('163.67')),
#  ('macaubas', Decimal('222.44')),
#  ('santo antonio do descoberto', Decimal('171.60')),
#  ('santa rosa', Decimal('156.00')),
#  ('gramado', Decimal('152.53')),
#  ('porto uniao', Decimal('143.00')),
#  ('itaberai', Decimal('143.00')),
#  ('timoteo', Decimal('169.98')),
#  ('rio do antonio', Decimal('214.50')),
#  ('pitangui', Decimal('162.50')),
#  ('tubarao', Decimal('159.68')),
#  ('varzea grande', Decimal('163.43')),
#  ('itapipoca', Decimal('169.00')),
#  ("dias d'avila", Decimal('154.92')),
#  ('sao joao do manhuacu', Decimal('143.00')),
#  ('santo augusto', Decimal('158.89')),
#  ('bananeiras', Decimal('171.60')),
#  ('aperibe', Decimal('178.75')),
#  ('pitangueiras', Decimal('151.94')),
#  ('igrejinha', Decimal('168.24')),
#  ('estacao', Decimal('143.00')),
#  ('joao monlevade', Decimal('165.43')),
#  ('gaurama', Decimal('190.67')),
#  ('balsamo', Decimal('214.50')),
#  ('guaicara', Decimal('160.88')),
#  ('vianopolis', Decimal('190.67')),
#  ('francisco beltrao', Decimal('162.25')),
#  ('saudades', Decimal('250.25')),
#  ('valenca do piaui', Decimal('143.00')),
#  ('balsas', Decimal('168.24')),
#  ('ipiranga', Decimal('143.00')),
#  ('machado', Decimal('156.62')),
#  ('capao da canoa', Decimal('169.34')),
#  ('osvaldo cruz', Decimal('187.69')),
#  ('itumbiara', Decimal('182.72')),
#  ('veranopolis', Decimal('206.56')),
#  ('aripuana', Decimal('143.00')),
#  ('sarzedo', Decimal('150.94')),
#  ('varre-sai', Decimal('143.00')),
#  ('parati', Decimal('154.00')),
#  ('guanambi', Decimal('154.59')),
#  ('itabirito', Decimal('162.72')),
#  ('abaetetuba', Decimal('182.00')),
#  ('anaurilandia', Decimal('143.00')),
#  ('cataguases', Decimal('156.00')),
#  ('gameleiras', Decimal('143.00')),
#  ('rio verde', Decimal('202.40')),
#  ('iracemapolis', Decimal('158.89')),
#  ('apuiares', Decimal('143.00')),
#  ('engenheiro coelho', Decimal('143.00')),
#  ('ilha comprida', Decimal('143.00')),
#  ('cacador', Decimal('150.15')),
#  ('caravelas', Decimal('143.00')),
#  ('itapuranga', Decimal('163.43')),
#  ('astorga', Decimal('143.00')),
#  ('socorro', Decimal('173.11')),
#  ('nova cruz', Decimal('143.00')),
#  ('saquarema', Decimal('158.54')),
#  ('pacaja', Decimal('143.00')),
#  ('cedral', Decimal('143.00')),
#  ('muritiba', Decimal('143.00')),
#  ('ico', Decimal('160.88')),
#  ('sarandi', Decimal('143.00')),
#  ('cuite', Decimal('143.00')),
#  ('frutal', Decimal('165.00')),
#  ('godoy moreira', Decimal('143.00')),
#  ('uaua', Decimal('143.00')),
#  ('limoeiro do norte', Decimal('154.92')),
#  ('santa rita do araguaia', Decimal('143.00')),
#  ('iturama', Decimal('143.00')),
#  ('santa rosa de lima', Decimal('143.00')),
#  ('santa terezinha', Decimal('143.00')),
#  ('quissama', Decimal('165.00')),
#  ('itapiuna', Decimal('143.00')),
#  ('nilopolis', Decimal('157.70')),
#  ('queluz', Decimal('143.00')),
#  ('batatais', Decimal('158.32')),
#  ('poco fundo', Decimal('160.88')),
#  ('salto do jacui', Decimal('178.75')),
#  ('palmares', Decimal('143.00')),
#  ('lindoia', Decimal('158.89')),
#  ('urucurituba', Decimal('143.00')),
#  ('sao pedro', Decimal('166.83')),
#  ('brumado', Decimal('188.50')),
#  ('timbo', Decimal('157.30')),
#  ('cordeiros', Decimal('143.00')),
#  ('sao luis de montes belos', Decimal('178.75')),
#  ('brusque', Decimal('150.15')),
#  ('casimiro de abreu', Decimal('157.30')),
#  ('boa esperanca', Decimal('150.15')),
#  ('ibitinga', Decimal('156.00')),
#  ('valente', Decimal('158.89')),
#  ('alto paraiso de goias', Decimal('429.00')),
#  ('bom principio', Decimal('143.00')),
#  ('sao goncalo do rio abaixo', Decimal('214.50')),
#  ('nossa senhora do socorro', Decimal('153.21')),
#  ('tiangua', Decimal('143.00')),
#  ('rio bananal', Decimal('178.75')),
#  ('araxa', Decimal('171.22')),
#  ('piuma', Decimal('159.82')),
#  ('aurea', Decimal('143.00')),
#  ('tucurui', Decimal('168.24')),
#  ('parauapebas', Decimal('180.07')),
#  ('sao bernardo', Decimal('143.00')),
#  ('taruma', Decimal('158.89')),
#  ('ribeirao', Decimal('143.00')),
#  ('itajobi', Decimal('257.40')),
#  ('ijui', Decimal('181.50')),
#  ('lagoa vermelha', Decimal('143.00')),
#  ('ibirataia', Decimal('143.00')),
#  ('altamira', Decimal('154.44')),
#  ('bayeux', Decimal('204.29')),
#  ('santo antonio da patrulha', Decimal('151.41')),
#  ('lucelia', Decimal('143.00')),
#  ('lins', Decimal('161.20')),
#  ('maracanau', Decimal('172.44')),
#  ('comendador levy gasparian', Decimal('163.43')),
#  ('marechal candido rondon', Decimal('156.84')),
#  ('gaspar', Decimal('200.20')),
#  ('anchieta', Decimal('151.41')),
#  ('firminopolis', Decimal('143.00')),
#  ('itamarandiba', Decimal('196.63')),
#  ('canapi', Decimal('143.00')),
#  ('ipiabas', Decimal('178.75')),
#  ('mairinque', Decimal('165.88')),
#  ('victor graeff', Decimal('143.00')),
#  ('alcinopolis', Decimal('190.67')),
#  ('cambuci', Decimal('143.00')),
#  ('curitibanos', Decimal('178.75')),
#  ('pariquera-acu', Decimal('152.53')),
#  ('itagiba', Decimal('143.00')),
#  ('una', Decimal('143.00')),
#  ('ipaussu', Decimal('183.86')),
#  ('taguai', Decimal('157.30')),
#  ('anicuns', Decimal('143.00')),
#  ('chorrocho', Decimal('143.00')),
#  ('claudia', Decimal('214.50')),
#  ('paragominas', Decimal('150.53')),
#  ('ze doca', Decimal('143.00')),
#  ('capivari', Decimal('147.21')),
#  ('ibiam', Decimal('143.00')),
#  ('cocalinho', Decimal('214.50')),
#  ('moncoes', Decimal('143.00')),
#  ('sao simao', Decimal('143.00')),
#  ('jesuania', Decimal('171.60')),
#  ('pederneiras', Decimal('163.43')),
#  ('campo novo do parecis', Decimal('214.50')),
#  ('tres de maio', Decimal('166.83')),
#  ('catalao', Decimal('176.65')),
#  ('angra dos reis', Decimal('180.01')),
#  ('areia branca', Decimal('143.00')),
#  ('cacapava do sul', Decimal('200.20')),
#  ('paranaiba', Decimal('152.53')),
#  ('ipora', Decimal('151.41')),
#  ('santa cruz das palmeiras', Decimal('143.00')),
#  ('miguel pereira', Decimal('163.43')),
#  ('humaita', Decimal('143.00')),
#  ('varzea paulista', Decimal('155.83')),
#  ('bom sucesso', Decimal('143.00')),
#  ('dores do indaia', Decimal('183.86')),
#  ('louveira', Decimal('149.50')),
#  ('casca', Decimal('143.00')),
#  ('vargem alta', Decimal('143.00')),
#  ('camutanga', Decimal('143.00')),
#  ('floriano', Decimal('143.00')),
#  ('sao ludgero', Decimal('190.67')),
#  ('conceicao das pedras', Decimal('178.75')),
#  ('centenario do sul', Decimal('143.00')),
#  ('bandeirantes', Decimal('153.21')),
#  ('florai', Decimal('143.00')),
#  ('ibirama', Decimal('187.00')),
#  ('uruguaiana', Decimal('163.85')),
#  ('mossamedes', Decimal('143.00')),
#  ('bela cruz', Decimal('143.00')),
#  ('sao jose de ribamar', Decimal('143.00')),
#  ('aguas vermelhas', Decimal('286.00')),
#  ('natividade', Decimal('151.94')),
#  ('ibirite', Decimal('145.86')),
#  ('extrema', Decimal('152.75')),
#  ('ouricuri', Decimal('143.00')),
#  ('eldorado do sul', Decimal('143.00')),
#  ('tucano', Decimal('143.00')),
#  ('laranjal paulista', Decimal('168.24')),
#  ('agua branca', Decimal('171.60')),
#  ('tremembe', Decimal('150.53')),
#  ('parobe', Decimal('143.00')),
#  ('caraubas', Decimal('143.00')),
#  ('santo antonio do rio abaixo', Decimal('143.00')),
#  ('lajedo', Decimal('143.00')),
#  ('sao tomas de aquino', Decimal('190.67')),
#  ('garopaba', Decimal('192.74')),
#  ('itaiopolis', Decimal('196.63')),
#  ('araputanga', Decimal('214.50')),
#  ('sao joao batista', Decimal('143.00')),
#  ('nossa senhora de lourdes', Decimal('143.00')),
#  ('araguaia', Decimal('143.00')),
#  ('trombudo central', Decimal('143.00')),
#  ('manoel viana', Decimal('143.00')),
#  ('concordia do para', Decimal('143.00')),
#  ('aurora', Decimal('171.60')),
#  ('francisco badaro', Decimal('190.67')),
#  ('ilheus', Decimal('172.79')),
#  ('porto xavier', Decimal('200.20')),
#  ('conceicao do araguaia', Decimal('143.00')),
#  ('cardoso', Decimal('143.00')),
#  ('alegria', Decimal('143.00')),
#  ('caibi', Decimal('143.00')),
#  ('pirapetinga', Decimal('163.43')),
#  ('papucaia', Decimal('157.30')),
#  ('caldas novas', Decimal('166.83')),
#  ('pompeia', Decimal('201.88')),
#  ('colatina', Decimal('178.20')),
#  ('barroso', Decimal('195.00')),
#  ('venancio aires', Decimal('148.50')),
#  ('quedas do iguacu', Decimal('160.88')),
#  ('ampere', Decimal('143.00')),
#  ('sao sebastiao da serra', Decimal('143.00')),
#  ('sapiranga', Decimal('171.60')),
#  ('mateus leme', Decimal('158.89')),
#  ('matao', Decimal('159.50')),
#  ('joao pinheiro', Decimal('160.88')),
#  ('santa gertrudes', Decimal('169.00')),
#  ('itaqui', Decimal('270.11')),
#  ('barra de sao francisco', Decimal('143.00')),
#  ('lunardelli', Decimal('143.00')),
#  ('barra', Decimal('143.00')),
#  ('paranaita', Decimal('214.50')),
#  ('currais novos', Decimal('160.88')),
#  ('bom jardim de minas', Decimal('196.63')),
#  ('oliveira', Decimal('143.00')),
#  ('itapema', Decimal('156.00')),
#  ('ipira', Decimal('190.67')),
#  ('montalvania', Decimal('190.67')),
#  ('bom jesus do tocantins', Decimal('143.00')),
#  ('sao joao del rei', Decimal('157.94')),
#  ('iraucuba', Decimal('143.00')),
#  ('uniao de minas', Decimal('143.00')),
#  ('itapeva', Decimal('165.58')),
#  ('jaguarao', Decimal('178.75')),
#  ('paraguacu paulista', Decimal('143.00')),
#  ('imbe', Decimal('187.00')),
#  ('ouro fino', Decimal('205.56')),
#  ('torres', Decimal('176.65')),
#  ('itaperuna', Decimal('164.30')),
#  ('irece', Decimal('253.00')),
#  ('sao joao', Decimal('154.92')),
#  ('cha grande', Decimal('143.00')),
#  ('antonina do norte', Decimal('286.00')),
#  ('promissao', Decimal('143.00')),
#  ('paranapanema', Decimal('169.00')),
#  ('echapora', Decimal('214.50')),
#  ('materlandia', Decimal('143.00')),
#  ('utinga', Decimal('143.00')),
#  ('sao luiz gonzaga', Decimal('162.07')),
#  ('agua boa', Decimal('166.83')),
#  ('virginia', Decimal('143.00')),
#  ('espera feliz', Decimal('143.00')),
#  ('brotas', Decimal('154.92')),
#  ('salgado filho', Decimal('190.67')),
#  ('santana', Decimal('198.00')),
#  ('general carneiro', Decimal('143.00')),
#  ('mirandiba', Decimal('143.00')),
#  ('caconde', Decimal('157.30')),
#  ('terra rica', Decimal('143.00')),
#  ('nova santa rosa', Decimal('143.00')),
#  ('pirapora do bom jesus', Decimal('151.94')),
#  ('ararangua', Decimal('158.89')),
#  ('serra negra', Decimal('173.64')),
#  ('ronda alta', Decimal('262.17')),
#  ('paulo afonso', Decimal('165.00')),
#  ('guaramirim', Decimal('154.00')),
#  ('joacaba', Decimal('148.50')),
#  ('ibicarai', Decimal('143.00')),
#  ('cravinhos', Decimal('178.75')),
#  ('viana', Decimal('165.00')),
#  ('vargem grande do sul', Decimal('143.00')),
#  ('corumba de goias', Decimal('143.00')),
#  ('aquidauana', Decimal('143.00')),
#  ('sao martinho', Decimal('143.00')),
#  ('itu', Decimal('155.71')),
#  ('pantano grande', Decimal('143.00')),
#  ('porangaba', Decimal('143.00')),
#  ('tocantins', Decimal('143.00')),
#  ('diamantino', Decimal('143.00')),
#  ('urupes', Decimal('171.60')),
#  ('sirinhaem', Decimal('143.00')),
#  ('santos dumont', Decimal('149.50')),
#  ('mesquita', Decimal('180.63')),
#  ('caratinga', Decimal('163.76')),
#  ('itaocara', Decimal('160.88')),
#  ('piumhi', Decimal('190.67')),
#  ('crixas', Decimal('160.88')),
#  ('portalegre', Decimal('214.50')),
#  ('aruja', Decimal('159.58')),
#  ('jaguare', Decimal('153.21')),
#  ('rio negrinho', Decimal('154.00')),
#  ('rio manso', Decimal('143.00')),
#  ('taua', Decimal('143.00')),
#  ('raul soares', Decimal('166.83')),
#  ('presidente venceslau', Decimal('194.48')),
#  ('bocaiuva', Decimal('143.00')),
#  ('brazopolis', Decimal('143.00')),
#  ...]

# %% [markdown]
# # 8. Calculate the percentage of total revenue contributed by each product category.

# %%
query = """ select upper(products.product_category) category, 
round((sum(payments.payment_value)/(select sum(payment_value) from payments))*100,2) sales_percentage
from products join order_items
on products.product_id = order_items.product_id 
join payments
on payments.order_id = order_items.order_id
group by category
order by sales_percentage desc
"""

cur.execute(query)

data = cur.fetchall()
#data
df = pd.DataFrame(data, columns = ["Category", "Sales_percentage"])
df.head(5)
# Out:
#                Category  Sales_percentage
# 0        BED TABLE BATH           1529.75
# 1         HEALTH BEAUTY           1480.46
# 2  COMPUTER ACCESSORIES           1416.10
# 3  FURNITURE DECORATION           1277.51
# 4       WATCHES PRESENT           1276.65

# %% [markdown]
# # 9. Identify the correlation between product price and the number of times a product has been purchased.

# %%
query = """ select products.product_category,
count(order_items.product_id),
round(avg(order_items.price),2)
from products join order_items
on products.product_id = order_items.product_id
group by products.product_category"""

cur.execute(query)
data = cur.fetchall()
df = pd.DataFrame(data,columns = ["Category", "order_count","price"])

arr1 = df["order_count"]
arr2 = df["price"]

#correlation between price and number of times a product has been purchased
a = np.corrcoef([arr1,arr2])
print("the correlation is", a[0][-1])
# Out:
# the correlation is -0.1063151416715756

# %% [markdown]
# # 10. Calculate the total revenue generated by each seller, and rank them by revenue.

# %%
query = """ select *, dense_rank() over(order by revenue desc) as rn from
(select order_items.seller_id, sum(payments.payment_value)
revenue from order_items join payments
on order_items.order_id = payments.order_id
group by order_items.seller_id) as a """

cur.execute(query)
data = cur.fetchall()
df = pd.DataFrame(data, columns = ["seller_id", "revenue", "rank"])
df = df.head()
sns.barplot(x = "seller_id", y = "revenue", data = df)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # 11. Calculate the moving average of order values for each customer over their order history.

# %%
query = """select customer_id, order_purchase_timestamp, payment,
avg(payment) over(partition by customer_id order by order_purchase_timestamp
rows between 2 preceding and current row) as mov_avg
from
(select orders.customer_id, orders.order_purchase_timestamp, 
payments.payment_value as payment
from payments join orders
on payments.order_id = orders.order_id) as a"""
cur.execute(query)
data = cur.fetchall()
df = pd.DataFrame(data)
df
# Out:
#                                          0                    1       2  \
# 0         00012a2ce6f8dcda20d059ce98491703  2017-11-14 16:08:26  114.74
# 1         00012a2ce6f8dcda20d059ce98491703  2017-11-14 16:08:26  114.74
# 2         00012a2ce6f8dcda20d059ce98491703  2017-11-14 16:08:26  114.74
# 3         00012a2ce6f8dcda20d059ce98491703  2017-11-14 16:08:26  114.74
# 4         00012a2ce6f8dcda20d059ce98491703  2017-11-14 16:08:26  114.74
# ...                                    ...                  ...     ...
# 16206211  ffffe8b65bbe3087b653a978c870db99  2017-09-29 14:07:03   18.37
# 16206212  ffffe8b65bbe3087b653a978c870db99  2017-09-29 14:07:03   18.37
# 16206213  ffffe8b65bbe3087b653a978c870db99  2017-09-29 14:07:03   18.37
# 16206214  ffffe8b65bbe3087b653a978c870db99  2017-09-29 14:07:03   18.37
# 16206215  ffffe8b65bbe3087b653a978c870db99  2017-09-29 14:07:03   18.37
#
#                    3
# 0         114.739998
# 1         114.739998
# 2         114.739998
# 3         114.739998
# 4         114.739998
# ...              ...
# 16206211   18.370001
# 16206212   18.370001
# 16206213   18.370001
# 16206214   18.370001
# 16206215   18.370001
#
# [16206216 rows x 4 columns]

# %% [markdown]
# # 12. Calculate the cumulative sales per month for each year.

# %%
query = """select years, months , payment, sum(payment)
over(order by years, months) cumulative_sales from 
(select year(orders.order_purchase_timestamp) as years,
month(orders.order_purchase_timestamp) as months,
round(sum(payments.payment_value),2) as payment from orders join payments
on orders.order_id = payments.order_id
group by years, months order by years, months) as a
"""
cur.execute(query)
data = cur.fetchall()
df = pd.DataFrame(data)
df
# Out:
#        0   1             2             3
# 0   2016   9  3.934944e+04  3.934944e+04
# 1   2016  10  9.218115e+06  9.257464e+06
# 2   2016  12  3.060720e+03  9.260525e+06
# 3   2017   1  2.160413e+07  3.086466e+07
# 4   2017   2  4.553765e+07  7.640231e+07
# 5   2017   3  7.017872e+07  1.465810e+08
# 6   2017   4  6.517493e+07  2.117560e+08
# 7   2017   5  9.249534e+07  3.042513e+08
# 8   2017   6  7.975912e+07  3.840104e+08
# 9   2017   7  9.241174e+07  4.764221e+08
# 10  2017   8  1.052058e+08  5.816280e+08
# 11  2017   9  1.135309e+08  6.951589e+08
# 12  2017  10  1.216297e+08  8.167887e+08
# 13  2017  11  1.864017e+08  1.003190e+09
# 14  2017  12  1.370306e+08  1.140221e+09
# 15  2018   1  1.739407e+08  1.314162e+09
# 16  2018   2  1.548243e+08  1.468986e+09
# 17  2018   3  1.809057e+08  1.649892e+09
# 18  2018   4  1.810825e+08  1.830974e+09
# 19  2018   5  1.800212e+08  2.010995e+09
# 20  2018   6  1.597254e+08  2.170721e+09
# 21  2018   7  1.663804e+08  2.337101e+09
# 22  2018   8  1.594984e+08  2.496599e+09
# 23  2018   9  6.925683e+05  2.497292e+09
# 24  2018  10  9.198852e+04  2.497384e+09

# %% [markdown]
# # 13. Calculate the year-over-year growth rate of total sales.

# %%
query = """with a as(select year(orders.order_purchase_timestamp) as years,
round(sum(payments.payment_value),2) as payment from orders join payments
on orders.order_id = payments.order_id
group by years order by years)

select years, ((payment - lag(payment, 1) over(order by years))/
lag(payment, 1) over(order by years)) * 100 from a"""

cur.execute(query)
data = cur.fetchall()
df = pd.DataFrame(data, columns = ["years", "yoy % growth"])
df
# Out:
#    years  yoy % growth
# 0   2016           NaN
# 1   2017  12112.703758
# 2   2018     20.000924

# %% [markdown]
# # 14. Calculate the retention rate of customers, defined as the percentage of customers who make another purchase within 6 months of their first purchase.

# %%
query = """with a as (select customers.customer_id,
min(orders.order_purchase_timestamp) first_order
from customers join orders
on customers.customer_id = orders.customer_id
group by customers.customer_id),

b as (select a.customer_id, count(distinct orders.order_purchase_timestamp) next_order
from a join orders
on orders.customer_id = a.customer_id
and orders.order_purchase_timestamp > first_order
and orders.order_purchase_timestamp < 
date_add(first_order, interval 6 month)
group by a.customer_id) 

select 100 * (count( distinct a.customer_id)/ count(distinct b.customer_id)) 
from a left join b 
on a.customer_id = b.customer_id ;"""

cur.execute(query)
data = cur.fetchall()

data
# Out:
# [(None,)]

# %% [markdown]
# # 15. Identify the top 3 customers who spent the most money in each year.

# %%
query = """select years, customer_id, payment, d_rank
from
(select year(orders.order_purchase_timestamp) years,
orders.customer_id,
sum(payments.payment_value) payment,
dense_rank() over(partition by year(orders.order_purchase_timestamp)
order by sum(payments.payment_value) desc) d_rank
from orders join payments 
on payments.order_id = orders.order_id
group by year(orders.order_purchase_timestamp),
orders.customer_id) as a
where d_rank <= 3 ;"""

cur.execute(query)
data = cur.fetchall()
df = pd.DataFrame(data, columns = ["years","id","payment","rank"])
sns.barplot(x = "id", y = "payment", data = df, hue = "years")
plt.xticks(rotation = 90)
plt.show()
